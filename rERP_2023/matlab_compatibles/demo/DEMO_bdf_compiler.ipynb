# %%
import pandas as pd
import numpy as np
import os
import mne
from bdf_compiler import *  # epoching raw instances based on Matlab EEGLAB bin description files            
                            # the BDF.txt must only contain mutually exclusive bins
import warnings
warnings.simplefilter(action='ignore', category=Warning)
from PIL import Image

# %%
os.chdir('/home/amandalin047/session_20230428/data')
subj027_raw = mne.io.read_raw_eeglab('subj027.set')
os.chdir('/home/amandalin047/session_20230428/txt_files')
subj027_epochs = bin_based_epoch(subj027_raw, 'Crystal_List1Lengthy_bdf.txt', -0.1, 1.0, bc=None)
# Out:
# Reading /home/amandalin047/session_20230428/data/subj027.fdt
# ...

# %%
print(subj027_epochs.event_id)
for k in subj027_epochs.event_id: display(subj027_epochs[k])
# Out:
# {'sc_plaus': 223, 'wc_plaus': 225, 'some_kind_of_response_locked': 224, '3rd_word_in_medium_constraint': 155}
# <Epochs |  35 events (good & bad), -0.1 - 1 sec, baseline off, ~53 kB, data not loaded,
#  'sc_plaus': 35>
# <Epochs |  32 events (good & bad), -0.1 - 1 sec, baseline off, ~53 kB, data not loaded,
#  'wc_plaus': 32>
# <Epochs |  45 events (good & bad), -0.1 - 1 sec, baseline off, ~53 kB, data not loaded,
#  'some_kind_of_response_locked': 45>
# <Epochs |  22 events (good & bad), -0.1 - 1 sec, baseline off, ~53 kB, data not loaded,
#  '3rd_word_in_medium_constraint': 22>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread('/mnt/c/Users/amand/Photos/Screenshots/subj027_binSummary.png')
plt.imshow(img);

# %%
os.chdir('/home/amandalin047/session_20230428/data')
S1_raw = mne.io.read_raw_eeglab('S1.set')
os.chdir('/home/amandalin047/session_20230428/txt_files')
S1_epochs = bin_based_epoch(S1_raw, 'S1_randomBDF.txt', -0.1, 1.0, bc=None)
# Out:
# Reading /home/amandalin047/session_20230428/data/S1.fdt
# ...

# %%
print(S1_epochs.event_id)
for k in S1_epochs.event_id: display(S1_epochs[k])
# Out:
# {'LVF_Grammatical_Correct': 152, 'RVF_Grammatical_Correct': 153, 'response_locked': 157, 'fixation': 156, 'adv_LVF_UngramNP': 154}
# <Epochs |  63 events (good & bad), -0.1 - 1 sec, baseline off, ~51 kB, data not loaded,
#  'LVF_Grammatical_Correct': 63>
# <Epochs |  66 events (good & bad), -0.1 - 1 sec, baseline off, ~51 kB, data not loaded,
#  'RVF_Grammatical_Correct': 66>
# <Epochs |  401 events (good & bad), -0.1 - 1 sec, baseline off, ~51 kB, data not loaded,
#  'response_locked': 401>
# <Epochs |  395 events (good & bad), -0.1 - 1 sec, baseline off, ~51 kB, data not loaded,
#  'fixation': 395>
# <Epochs |  34 events (good & bad), -0.1 - 1 sec, baseline off, ~51 kB, data not loaded,
#  'adv_LVF_UngramNP': 34>

# %%
img = mpimg.imread('/mnt/c/Users/amand/Photos/Screenshots/S1_binSummary.png')
plt.imshow(img);

# %%
# What's new in this updated version of bdf_compiler.py is that Epochs can be accessed with the actual bin names
S1_epochs['LVF_Grammatical_Correct']
# Out:
# <Epochs |  63 events (good & bad), -0.1 - 1 sec, baseline off, ~51 kB, data not loaded,
#  'LVF_Grammatical_Correct': 63>
